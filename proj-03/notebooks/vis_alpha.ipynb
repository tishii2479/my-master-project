# %%
import os
import json

import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("ggplot")

# %%
records = []
for p in os.listdir("../log/alpha/"):
    with open(f"../log/alpha/{p}", "r") as f:
        d = json.load(f)
        records.append(pd.json_normalize(d))

# %%
df = pd.concat(records).sort_values(by="args.alpha").reset_index(drop=True)

# %%
df.plot(
    "args.alpha",
    [
        "evaluations.Uplift@10",
        "evaluations.Uplift@30",
        "evaluations.Uplift@100",
    ],
)
# Out:
# <Axes: xlabel='args.alpha'>

# %%
df.plot(
    "args.alpha",
    [
        "evaluations.Accuracy@10",
        "evaluations.Accuracy@30",
        "evaluations.Accuracy@100",
    ],
)
# Out:
# <Axes: xlabel='args.alpha'>

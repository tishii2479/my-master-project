# %%
import sys
sys.path.append("..")

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/ml-25m-imdb/movie_ml_imdb.csv", sep="\t")
df
# Out:
#        movieId                        title  \
# 0            1                    Toy Story
# 1            2                      Jumanji
# 2            3             Grumpier Old Men
# 3            4            Waiting to Exhale
# 4            5  Father of the Bride Part II
# ...        ...                          ...
# 62418   209157                           We
# 62419   209159           Window of the Soul
# 62420   209163                    Bad Poems
# 62421   209169                 A Girl Thing
# 62422   209171      Women of Devil's Island
#
#                                          genres_ml  year     tconst  \
# 0      Adventure|Animation|Children|Comedy|Fantasy  1995  tt0114709
# 1                       Adventure|Children|Fantasy  1995  tt0113497
# 2                                   Comedy|Romance  1995  tt0113228
# 3                             Comedy|Drama|Romance  1995  tt0114885
# 4                                           Comedy  1995  tt0113041
# ...

# %%
df = pd.read_csv("../data/ml-25m-imdb/nconst_info.csv", sep="\t")
df
# Out:
#            nconst        primaryName birthYear deathYear  \
# 0       nm0169505         Joel Cohen        \N        \N
# 1       nm0000158          Tom Hanks      1956        \N
# 2       nm0000741          Tim Allen      1953        \N
# 3       nm0725543        Don Rickles      1926      2017
# 4       nm0001815         Jim Varney      1949      2000
# ...           ...                ...       ...       ...
# 227643  nm2803658      Dániel Bálint      1985        \N
# 227644  nm6210812     Zsófia Tasnádi      1991        \N
# 227645  nm0550167  William Marrinson        \N        \N
# 227646  nm0022663    Tullio Altamura      1924        \N
# 227647  nm0709424    Federica Ranchi      1939        \N
#
#                                       primaryProfession  \
# 0                                 writer,actor,producer
# 1                             producer,actor,soundtrack
# 2                          actor,producer,miscellaneous
# ...

# %%
rating_df = pd.read_csv("../data/ml-25m/ratings.csv")
rating_df
# Out:
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 1              1      306     3.5  1147868817
# 2              1      307     5.0  1147868828
# 3              1      665     5.0  1147878820
# 4              1      899     3.5  1147868510
# ...          ...      ...     ...         ...
# 25000090  162541    50872     4.5  1240953372
# 25000091  162541    55768     2.5  1240951998
# 25000092  162541    56176     2.0  1240950697
# 25000093  162541    58559     4.0  1240953434
# 25000094  162541    63876     5.0  1240952515
#
# [25000095 rows x 4 columns]

# %%
rating_df.timestamp = pd.to_datetime(rating_df.timestamp, unit="s")

# %%
rating_df.groupby("userId").timestamp.min().hist()
# Out:
# <Axes: >

# %%
rating_df.userId.value_counts().describe()
# Out:
# count    162541.000000
# mean        153.807932
# std         268.047590
# min          20.000000
# 25%          36.000000
# 50%          71.000000
# 75%         162.000000
# max       32202.000000
# Name: count, dtype: float64

# %%
rating_df
# Out:
#           userId  movieId  rating           timestamp
# 0              1      296     5.0 2006-05-17 15:34:04
# 1              1      306     3.5 2006-05-17 12:26:57
# 2              1      307     5.0 2006-05-17 12:27:08
# 3              1      665     5.0 2006-05-17 15:13:40
# 4              1      899     3.5 2006-05-17 12:21:50
# ...          ...      ...     ...                 ...
# 25000090  162541    50872     4.5 2009-04-28 21:16:12
# 25000091  162541    55768     2.5 2009-04-28 20:53:18
# 25000092  162541    56176     2.0 2009-04-28 20:31:37
# 25000093  162541    58559     4.0 2009-04-28 21:17:14
# 25000094  162541    63876     5.0 2009-04-28 21:01:55
#
# [25000095 rows x 4 columns]

# %%
rating_df.userId.value_counts().hist(range=(20, 200))
# Out:
# <Axes: >

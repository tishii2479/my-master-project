# %%
import pandas as pd

# %%
bts_df = pd.read_csv("open_bandit_dataset/bts/all/all.csv", index_col=0, nrows=10000)
bts_df["item_id"].value_counts().hist()
# Out:
# <Axes: >

# %%
random_df = pd.read_csv("open_bandit_dataset/random/all/all.csv", nrows=10000, index_col=0)
random_df["item_id"].value_counts().hist()
# Out:
# <Axes: >

# %%
bts_df["user-item_affinity_8"].sum()
# Out:
# 0.0
